# %% [markdown]
# <a href="https://colab.research.google.com/github/muthu-selvakumar/AIML-course/blob/Pandas_Tasks_Assigment/Pandas_Tasks_adult_data(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# read the data

# %%
filepath = '/content/adult.csv'
adult_data = pd.read_csv(filepath)
adult_data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %% [markdown]
# Display the first 5 rows of the dataset.

# %%
adult_data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %% [markdown]
# summary of the DataFrame

# %%
adult_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# descriptive statistics for numeric columns

# %%
adult_data.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %% [markdown]
# Display the column names of the DataFrame.

# %%
adult_data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %% [markdown]
# unique values in the 'workclass' column.

# %%
adult_data['workclass'].unique()
# Out:
# array(['Private', 'Local-gov', '?', 'Self-emp-not-inc', 'Federal-gov',
#        'State-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %% [markdown]
# Create a new column 'income_binary' where <=50K is 0 and >50K is 1.

# %%
adult_data['income_binary'] = adult_data['income'].apply(lambda x: 1 if x == '>50K' else 0)
display(adult_data.head())
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
# ...

# %% [markdown]
# Create a new column 'age_group' categorizing ages into 'Youth' (< 30), 'Adult' (30-60), and 'Senior' (60+).

# %%
def categorize_age(age):
    if age < 30:
        return 'Youth'
    elif 30 <= age < 60:
        return 'Adult'
    else:
        return 'Senior'

adult_data['age_group'] = adult_data['age'].apply(categorize_age)
display(adult_data.head())
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
# ...

# %% [markdown]
# Rename the 'educational-num' column to 'education_num'.
#
# *   List item
# *   List item

# %% [markdown]
# Replace the missing values represented by '?' in 'workclass' and 'occupation' columns with 'Unknown'.

# %% [markdown]
# Calculate the average age for each workclass.

# %%
# Calculate the average age for each workclass
average_age_by_workclass = adult_data.groupby('workclass')['age'].mean()
print(average_age_by_workclass)
# Out:
# workclass
# ?                   40.141122
# Federal-gov         42.577514
# Local-gov           41.676020
# Never-worked        19.900000
# Private             36.903144
# Self-emp-inc        45.799410
# Self-emp-not-inc    45.332470
# State-gov           39.512367
# Without-pay         47.285714
# Name: age, dtype: float64

# %% [markdown]
# Find the total capital-gain for each gender.

# %%
total_capital_gain_by_gender = adult_data.groupby('gender')['capital-gain'].sum()
print(total_capital_gain_by_gender)
# Out:
# gender
# Female     9403120
# Male      43300701
# Name: capital-gain, dtype: int64

# %% [markdown]
# Get the count of each marital-status category.

# %%
marital_status_counts = adult_data['marital-status'].value_counts()
print(marital_status_counts)
# Out:
# marital-status
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: count, dtype: int64

# %% [markdown]
# Find the mean hours-per-week worked by individuals in different education levels.

# %%
mean_hours_per_week_by_education = adult_data.groupby('education')['hours-per-week'].mean()
print(mean_hours_per_week_by_education)
# Out:
# education
# 10th            36.986321
# 11th            33.952539
# 12th            35.374429
# 1st-4th         38.761134
# 5th-6th         38.923379
# 7th-8th         39.003141
# 9th             38.359788
# Assoc-acdm      40.809494
# Assoc-voc       41.658418
# Bachelors       42.482492
# Doctorate       46.582492
# HS-grad         40.640775
# Masters         43.575837
# Preschool       36.566265
# Prof-school     47.579137
# Some-college    38.865784
# Name: hours-per-week, dtype: float64

# %% [markdown]
# Calculate the mean, median, and standard deviation of 'fnlwgt' for each race.

# %%
fnlwgt_stats_by_race = adult_data.groupby('race')['fnlwgt'].agg(['mean', 'median', 'std'])
print(fnlwgt_stats_by_race)
# Out:
#                              mean    median            std
# race
# Amer-Indian-Eskimo  120110.985106  101579.0   94655.908850
# Asian-Pac-Islander  159796.946675  139850.0   86997.647681
# Black               230485.070438  208266.0  125445.929357
# Other               195715.689655  188066.5   94063.712981
# White               186894.995738  177287.0  102637.466726

# %% [markdown]
# Get the unique values and their counts for the 'native-country' column

# %%
native_country_counts = adult_data['native-country'].value_counts()
print(native_country_counts)
# Out:
# native-country
# United-States                 43832
# Mexico                          951
# ?                               857
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# ...

# %% [markdown]
# Filter the dataset to include only individuals with income >50K.

# %%
adult_data_high_income = adult_data[adult_data['income'] == '>50K']
display(adult_data_high_income.head())
# Out:
#     age         workclass  fnlwgt     education  educational-num  \
# 2    28         Local-gov  336951    Assoc-acdm               12
# 3    44           Private  160323  Some-college               10
# 7    63  Self-emp-not-inc  104626   Prof-school               15
# 10   65           Private  184454       HS-grad                9
# 14   48           Private  279724       HS-grad                9
#
#         marital-status         occupation relationship   race gender  \
# 2   Married-civ-spouse    Protective-serv      Husband  White   Male
# 3   Married-civ-spouse  Machine-op-inspct      Husband  Black   Male
# 7   Married-civ-spouse     Prof-specialty      Husband  White   Male
# 10  Married-civ-spouse  Machine-op-inspct      Husband  White   Male
# 14  Married-civ-spouse  Machine-op-inspct      Husband  White   Male
#
#     capital-gain  capital-loss  hours-per-week native-country income  \
# 2              0             0              40  United-States   >50K
# ...

# %% [markdown]
# Sort the dataset by age in descending order.

# %%
adult_data_sorted_by_age = adult_data.sort_values(by='age', ascending=False)
display(adult_data_sorted_by_age.head())
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 18584   90           Private   52386  Some-college               10
# 47977   90                 ?  313986       HS-grad                9
# 7419    90  Self-emp-not-inc  122348   Prof-school               15
# 10735   90         Local-gov  188242       HS-grad                9
# 35770   90           Private   84553       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 18584       Never-married      Other-service  Not-in-family
# 47977  Married-civ-spouse                  ?        Husband
# 7419   Married-civ-spouse     Prof-specialty        Husband
# 10735       Never-married       Craft-repair      Own-child
# 35770  Married-civ-spouse  Machine-op-inspct        Husband
#
#                      race gender  capital-gain  capital-loss  hours-per-week  \
# 18584  Asian-Pac-Islander   Male             0             0              35
# ...

# %% [markdown]
# Filter the dataset to include only individuals who work more than 40 hours per week.

# %%
adult_data_over_40_hours = adult_data[adult_data['hours-per-week'] > 40]
display(adult_data_over_40_hours.head())
# Out:
#     age workclass  fnlwgt  education  educational-num      marital-status  \
# 1    38   Private   89814    HS-grad                9  Married-civ-spouse
# 14   48   Private  279724    HS-grad                9  Married-civ-spouse
# 15   43   Private  346189    Masters               14  Married-civ-spouse
# 19   40   Private   85019  Doctorate               16  Married-civ-spouse
# 20   34   Private  107914  Bachelors               13  Married-civ-spouse
#
#            occupation relationship                race gender  capital-gain  \
# 1     Farming-fishing      Husband               White   Male             0
# 14  Machine-op-inspct      Husband               White   Male          3103
# 15    Exec-managerial      Husband               White   Male             0
# 19     Prof-specialty      Husband  Asian-Pac-Islander   Male             0
# 20       Tech-support      Husband               White   Male             0
#
# ...

# %% [markdown]
# Calculate the percentage of missing values in each column.

# %%
missing_values_percentage = (adult_data.isnull().sum() / len(adult_data)) * 100
print("Percentage of missing values per column:\n", missing_values_percentage)
# Out:
# Percentage of missing values per column:
#  age                0.0
# workclass          0.0
# fnlwgt             0.0
# education          0.0
# educational-num    0.0
# marital-status     0.0
# occupation         0.0
# relationship       0.0
# race               0.0
# gender             0.0
# capital-gain       0.0
# capital-loss       0.0
# hours-per-week     0.0
# native-country     0.0
# income             0.0
# income_binary      0.0
# age_group          0.0
# dtype: float64

# %% [markdown]
# Calculate the median income by education level and gender.

# %%
median_income_by_education_gender = adult_data.groupby(['education', 'gender'])['income_binary'].median()
print(median_income_by_education_gender)
# Out:
# education     gender
# 10th          Female    0.0
#               Male      0.0
# 11th          Female    0.0
#               Male      0.0
# 12th          Female    0.0
#               Male      0.0
# 1st-4th       Female    0.0
#               Male      0.0
# 5th-6th       Female    0.0
#               Male      0.0
# 7th-8th       Female    0.0
#               Male      0.0
# 9th           Female    0.0
#               Male      0.0
# Assoc-acdm    Female    0.0
#               Male      0.0
# Assoc-voc     Female    0.0
#               Male      0.0
# Bachelors     Female    0.0
#               Male      1.0
# Doctorate     Female    1.0
#               Male      1.0
# HS-grad       Female    0.0
#               Male      0.0
# Masters       Female    0.0
#               Male      1.0
# Preschool     Female    0.0
#               Male      0.0
# Prof-school   Female    0.0
#               Male      1.0
# Some-college  Female    0.0
#               Male      0.0
# ...

# %% [markdown]
# Find the top 3 occupations with the highest average capital-gain.

# %%
top_3_occupations_capital_gain = adult_data.groupby('occupation')['capital-gain'].mean().nlargest(3)
print("Top 3 occupations with the highest average capital-gain:\n", top_3_occupations_capital_gain)
# Out:
# Top 3 occupations with the highest average capital-gain:
#  occupation
# Prof-specialty     2745.918017
# Exec-managerial    2277.755504
# Sales              1266.898256
# Name: capital-gain, dtype: float64

# %% [markdown]
# Filter the dataset to include individuals who are 'Married-civ-spouse' and have an income >50K.

# %%
married_high_income = adult_data[(adult_data['marital-status'] == 'Married-civ-spouse') & (adult_data['income'] == '>50K')]
display(married_high_income.head())
# Out:
#     age         workclass  fnlwgt     education  educational-num  \
# 2    28         Local-gov  336951    Assoc-acdm               12
# 3    44           Private  160323  Some-college               10
# 7    63  Self-emp-not-inc  104626   Prof-school               15
# 10   65           Private  184454       HS-grad                9
# 14   48           Private  279724       HS-grad                9
#
#         marital-status         occupation relationship   race gender  \
# 2   Married-civ-spouse    Protective-serv      Husband  White   Male
# 3   Married-civ-spouse  Machine-op-inspct      Husband  Black   Male
# 7   Married-civ-spouse     Prof-specialty      Husband  White   Male
# 10  Married-civ-spouse  Machine-op-inspct      Husband  White   Male
# 14  Married-civ-spouse  Machine-op-inspct      Husband  White   Male
#
#     capital-gain  capital-loss  hours-per-week native-country income  \
# 2              0             0              40  United-States   >50K
# ...

# %% [markdown]
# Create 5 different charts and write your observations from the chart as comment

# %% [markdown]
# ## Chart 1: Income distribution by Age Group (Bar Plot)
#
# ### Subtask:
# Create a bar plot showing the proportion of high income individuals (>50K) for each age group (Youth, Adult, Senior) and add an observation.

# %% [markdown]
# **Reasoning**:
# To visualize the proportion of high-income individuals by age group as requested, I will create a bar plot using the `income_proportion_by_age_group` DataFrame. This directly addresses the first instruction of the subtask.

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='age_group', y='income_binary', data=income_proportion_by_age_group, palette='viridis')
plt.xlabel('Age Group')
plt.ylabel('Proportion of High Income (>50K)')
plt.title('Proportion of High Income by Age Group')
plt.show()
# Out:
# /tmp/ipython-input-2727946978.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='age_group', y='income_binary', data=income_proportion_by_age_group, palette='viridis')

# %% [markdown]
# **Reasoning**:
# The previous code generated a FutureWarning because `palette` was used without `hue`. To address this, I will explicitly set `hue` to 'age_group' and `legend` to `False` in the `sns.barplot` function, as suggested by the warning.

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='age_group', y='income_binary', data=income_proportion_by_age_group, hue='age_group', palette='viridis', legend=False)
plt.xlabel('Age Group')
plt.ylabel('Proportion of High Income (>50K)')
plt.title('Proportion of High Income by Age Group')
plt.show()

# %% [markdown]
# ```markdown
# Observation:
# The 'Adult' age group (30-60 years old) has the highest proportion of individuals with high income (>50K), followed by 'Senior' (60+ years old), and then 'Youth' (< 30 years old) has the lowest proportion.
# ```

# %% [markdown]
# ## Chart 2: Distribution of Workclass (Count Plot)
#
# ### Subtask:
# Create a count plot to visualize the distribution of individuals across different workclass categories and add an observation.

# %% [markdown]
# **Reasoning**:
# To visualize the distribution of 'workclass' categories, I will use `seaborn.countplot` as instructed, setting appropriate labels, title, and rotating x-axis labels for readability.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='workclass', data=adult_data, palette='viridis')
plt.xlabel('Workclass')
plt.ylabel('Count')
plt.title('Distribution of Workclass Categories')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-107672575.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='workclass', data=adult_data, palette='viridis')

# %% [markdown]
# **Reasoning**:
# The previous code generated a FutureWarning because `palette` was used without `hue`. To address this, I will explicitly set `hue` to 'workclass' and `legend` to `False` in the `sns.countplot` function, as suggested by the warning.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='workclass', data=adult_data, hue='workclass', palette='viridis', legend=False)
plt.xlabel('Workclass')
plt.ylabel('Count')
plt.title('Distribution of Workclass Categories')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ```markdown
# Observation:
# The 'Private' workclass category is by far the most frequent, indicating that a large majority of individuals in this dataset are employed in the private sector. 'Self-emp-not-inc' and 'Local-gov' are the next most common categories. Conversely, 'Without-pay' and 'Never-worked' are the least frequent workclass categories, representing a very small portion of the dataset.
# ```

# %% [markdown]
# ```markdown
# Observation:
# The 'Private' workclass category is by far the most frequent, indicating that a large majority of individuals in this dataset are employed in the private sector. 'Self-emp-not-inc' and 'Local-gov' are the next most common categories. Conversely, 'Without-pay' and 'Never-worked' are the least frequent workclass categories, representing a very small portion of the dataset.
# ```

# %% [markdown]
# Observation:
# The 'Private' workclass category is by far the most frequent, indicating that a large majority of individuals in this dataset are employed in the private sector. 'Self-emp-not-inc' and 'Local-gov' are the next most common categories. Conversely, 'Without-pay' and 'Never-worked' are the least frequent workclass categories, representing a very small portion of the dataset.

# %% [markdown]
# ## Chart 3: Distribution of Education Levels (Count Plot)
#
# ### Subtask:
# Create a count plot to visualize the distribution of individuals across different education levels and add an observation.
#
# #### Instructions
# 1. Create a count plot using `seaborn.countplot()` to visualize the distribution of the 'education' column from the `adult_data` DataFrame. You can set the figure size to (14, 7).
# 2. Set the x-axis label to 'Education Level' and the y-axis label to 'Count'.
# 3. Set the title of the plot to 'Distribution of Education Levels'.
# 4. Rotate the x-axis labels by 45 degrees to prevent overlap and improve readability using `plt.xticks(rotation=45, ha='right')`.
# 5. Display the plot using `plt.show()`.
# 6. Add an observation in a markdown cell about the distribution of education levels.

# %% [markdown]
# **Reasoning**:
# To visualize the distribution of education levels, I will use `seaborn.countplot` as instructed, setting appropriate labels, title, and rotating x-axis labels for readability.

# %%
plt.figure(figsize=(14, 7))
sns.countplot(x='education', data=adult_data, hue='education', palette='viridis', legend=False)
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.title('Distribution of Education Levels')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ```markdown
# Observation:
# HS-grad is the most common education level in the dataset, followed closely by Some-college and Bachelors. This suggests a significant portion of the population has at least a high school diploma or some post-secondary education. Education levels such as Preschool, 1st-4th, and 5th-6th are the least frequent, indicating a smaller number of individuals with very low levels of formal education.
# ```

# %% [markdown]
# ```markdown
# Observation:
# HS-grad is the most common education level in the dataset, followed closely by Some-college and Bachelors. This suggests a significant portion of the population has at least a high school diploma or some post-secondary education. Education levels such as Preschool, 1st-4th, and 5th-6th are the least frequent, indicating a smaller number of individuals with very low levels of formal education.
# ```

# %% [markdown]
# ```markdown
# Observation:
# HS-grad is the most common education level in the dataset, followed closely by Some-college and Bachelors. This suggests a significant portion of the population has at least a high school diploma or some post-secondary education. Education levels such as Preschool, 1st-4th, and 5th-6th are the least frequent, indicating a smaller number of individuals with very low levels of formal education.
# ```

# %% [markdown]
# ## Chart 4: Distribution of Gender (Count Plot)
#
# ### Subtask:
# Create a count plot to visualize the distribution of individuals by gender and add an observation.
#
# #### Instructions
# 1. Create a count plot using `seaborn.countplot()` to visualize the distribution of the 'gender' column from the `adult_data` DataFrame. You can set the figure size to (8, 5).
# 2. Set the x-axis label to 'Gender' and the y-axis label to 'Count'.
# 3. Set the title of the plot to 'Distribution of Gender'.
# 4. Display the plot using `plt.show()`.
# 5. Add an observation in a markdown cell about the distribution of gender.

# %% [markdown]
# ```markdown
# ## Chart 4: Distribution of Gender (Count Plot)
#
# ### Subtask:
# Create a count plot to visualize the distribution of individuals by gender and add an observation.
#
# #### Instructions
# 1. Create a count plot using `seaborn.countplot()` to visualize the distribution of the 'gender' column from the `adult_data` DataFrame. You can set the figure size to (8, 5).
# 2. Set the x-axis label to 'Gender' and the y-axis label to 'Count'.
# 3. Set the title of the plot to 'Distribution of Gender'.
# 4. Display the plot using `plt.show()`.
# 5. Add an observation in a markdown cell about the distribution of gender.
# ```

# %% [markdown]
# ## Chart 4: Distribution of Gender (Count Plot)
#
# ### Subtask:
# Create a count plot to visualize the distribution of individuals by gender and add an observation.
#
# #### Instructions
# 1. Create a count plot using `seaborn.countplot()` to visualize the distribution of the 'gender' column from the `adult_data` DataFrame. You can set the figure size to (8, 5).
# 2. Set the x-axis label to 'Gender' and the y-axis label to 'Count'.
# 3. Set the title of the plot to 'Distribution of Gender'.
# 4. Display the plot using `plt.show()`.
# 5. Add an observation in a markdown cell about the distribution of gender.

# %% [markdown]
# **Reasoning**:
# To visualize the distribution of gender, I will use `seaborn.countplot` as instructed, setting appropriate labels and title.

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='gender', data=adult_data, hue='gender', palette='viridis', legend=False)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distribution of Gender')
plt.show()

# %% [markdown]
# ```markdown
# Observation:
# Male individuals significantly outnumber female individuals in this dataset. This indicates a gender imbalance, with a larger representation of males. Further analysis might be needed to understand if this imbalance affects other demographic or income-related trends.
# ```

# %% [markdown]
# ```markdown
# Observation:
# Male individuals significantly outnumber female individuals in this dataset. This indicates a gender imbalance, with a larger representation of males. Further analysis might be needed to understand if this imbalance affects other demographic or income-related trends.
# ```

# %% [markdown]
# ## Chart 3: Age Distribution (Histogram)
#
# ### Subtask:
# Generate a histogram to show the distribution of ages in the dataset and add an observation.

# %% [markdown]
# **Reasoning**:
# To visualize the distribution of age, I will use `seaborn.histplot` as instructed, setting appropriate labels, title, and displaying the plot.

# %% [markdown]
# **Reasoning**:
# Generate a histogram to show the distribution of ages in the dataset, as instructed.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(adult_data['age'], bins=20, kde=True, color='skyblue')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age')
plt.show()

# %% [markdown]
# ```markdown
# Observation:
# The age distribution shows a right-skewed pattern, with a majority of individuals falling in the younger to middle-adult age ranges (20s to 40s). The frequency gradually decreases as age increases, indicating fewer older individuals in the dataset. There are noticeable peaks in the 20-30 and 30-40 age bins.
# ```

# %% [markdown]
# ```markdown
# Observation:
# The age distribution shows a right-skewed pattern, with a majority of individuals falling in the younger to middle-adult age ranges (20s to 40s). The frequency gradually decreases as age increases, indicating fewer older individuals in the dataset. There are noticeable peaks in the 20-30 and 30-40 age bins.
# ```

# %% [markdown]
# ## Chart 4: Hours-per-week by Gender (Box Plot)
#
# ### Subtask:
# Create a box plot to compare the distribution of hours-per-week worked between different genders and add an observation.

# %% [markdown]
# **Reasoning**:
# To visualize the distribution of 'hours-per-week' by 'gender', I will use `seaborn.boxplot` as instructed, setting appropriate labels, title, and explicitly handling the `palette` and `hue` parameters for clarity.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='gender', y='hours-per-week', data=adult_data, hue='gender', palette='viridis', legend=False)
plt.xlabel('Gender')
plt.ylabel('Hours per Week')
plt.title('Distribution of Hours per Week by Gender')
plt.show()

# %% [markdown]
# ```markdown
# Observation:
# Both male and female individuals show a median of 40 hours per week. However, the box plot for males appears to be slightly wider with a higher upper quartile and more outliers extending to higher hours, suggesting a greater variability and a tendency for some males to work more hours per week compared to females. The interquartile range for males also seems slightly larger, indicating a broader spread of typical working hours.
# ```

# %% [markdown]
# ```markdown
# Observation:
# Both male and female individuals show a median of 40 hours per week. However, the box plot for males appears to be slightly wider with a higher upper quartile and more outliers extending to higher hours, suggesting a greater variability and a tendency for some males to work more hours per week compared to females. The interquartile range for males also seems slightly larger, indicating a broader spread of typical working hours.
# ```

# %% [markdown]
# ## Chart 5: Marital Status Distribution (Bar Plot)
#
# ### Subtask:
# Generate a bar plot to show the count of each marital status category and add an observation.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   **Income by Age Group:** The 'Adult' age group (30-60 years old) exhibits the highest proportion of high-income individuals ($>$50K), followed by 'Senior' (60+ years old), with 'Youth' ($<$30 years old) having the lowest proportion.
# *   **Workclass Distribution:** The 'Private' sector is the most prevalent workclass, indicating a significant majority of individuals are employed in private companies. Conversely, 'Without-pay' and 'Never-worked' categories are the least frequent.
# *   **Age Distribution:** The age distribution is right-skewed, with most individuals concentrated in the younger to middle-adult age ranges (20s to 40s), and frequency gradually decreasing in older age groups. Noticeable peaks occur in the 20-30 and 30-40 age bins.
# *   **Hours per Week by Gender:** Both male and female individuals show a median of 40 hours per week. However, males display greater variability in working hours, with a higher upper quartile and more outliers extending to higher hours, suggesting a tendency for some males to work more hours compared to females.
#
# ### Insights or Next Steps
#
# *   The findings suggest potential areas for further investigation into socioeconomic factors influencing income distribution across age groups and gender-based differences in work patterns.
# *   Given the significant imbalance in workclass distribution, analyzing how workclass influences other variables like income or education level could provide valuable insights.
